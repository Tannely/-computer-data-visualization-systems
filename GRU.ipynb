# %% [markdown]
# Створити RNN для семантичного аналізу тексту з використанням:моделі GRU.
# Розробити власну архітектуру, кількість рекурентних шарів, функції
# активації, вибрати оптимізатор.
# Отримати для двох моделей по дві рецензії (позитивну і негативну).

# %%
import numpy as np
from tensorflow.keras.layers import Dense, GRU, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

positive_reviews = [
    "Яскраве сонечко, безхмарне небо і приємна прохолода - ідеальна комбінація для відпочинку на свіжому повітрі."]

negative_reviews = [
    "Несподівані дощі змочили всі плани на вихідні! Сильний вітер розкидав усю метушню по вулицях."]

# Об'єднання рецензій
reviews = positive_reviews + negative_reviews
count_positive = len(positive_reviews)
count_negative = len(negative_reviews)
total_reviews = count_positive + count_negative

# Токенізація тексту
max_words_count = 500
max_text_len = 10
tokenizer = Tokenizer(num_words=max_words_count, filters='!–"—#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(reviews)

# Перетворення тексту в числову послідовність 
dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(reviews[0][:100])

data = tokenizer.texts_to_sequences(reviews)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(list(tokenizer.word_index.items()))
# Створення вхідних та вихідних даних для моделі
X = data_pad
Y = np.array([1] * count_positive + [0] * count_negative)

# Випадкове перемішування даних
indices = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indices]
Y = Y[indices]

# Побудова моделі GRU
model = Sequential()
model.add(Embedding(max_words_count, 128, input_length=max_text_len))
model.add(GRU(128, return_sequences=True))
model.add(GRU(64, return_sequences=True))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Компіляція та тренування моделі
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
history = model.fit(X, Y, batch_size=32, epochs=30)
# Out:
# [('яскраве', 1), ('сонечко', 1), ('безхмарне', 1), ('небо', 1), ('і', 1), ('приємна', 1), ('прохолода', 1), ('ідеальна', 1), ('комбінація', 1), ('для', 1)]
# Яскраве сонечко, безхмарне небо і приємна прохолода - ідеальна комбінація для відпочинку на свіжому
# [('на', 1), ('яскраве', 2), ('сонечко', 3), ('безхмарне', 4), ('небо', 5), ('і', 6), ('приємна', 7), ('прохолода', 8), ('ідеальна', 9), ('комбінація', 10), ('для', 11), ('відпочинку', 12), ('свіжому', 13), ('повітрі', 14), ('несподівані', 15), ('дощі', 16), ('змочили', 17), ('всі', 18), ('плани', 19), ('вихідні', 20), ('сильний', 21), ('вітер', 22), ('розкидав', 23), ('усю', 24), ('метушню', 25), ('по', 26), ('вулицях', 27)]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 10, 128)           64000
#
#  gru (GRU)                   (None, 10, 128)           99072
#
#  gru_1 (GRU)                 (None, 10, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 209,761
# Trainable params: 209,761
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.6990 - accuracy: 0.0000e+00
# Epoch 2/30
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6876 - accuracy: 0.5000
# Epoch 3/30
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6763 - accuracy: 1.0000
# Epoch 4/30
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6638 - accuracy: 1.0000
# Epoch 5/30
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6489 - accuracy: 1.0000
# Epoch 6/30
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6304 - accuracy: 1.0000
# Epoch 7/30
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6067 - accuracy: 1.0000
# Epoch 8/30
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5766 - accuracy: 1.0000
# Epoch 9/30
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5383 - accuracy: 1.0000
# Epoch 10/30
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4907 - accuracy: 1.0000
# Epoch 11/30
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4328 - accuracy: 1.0000
# Epoch 12/30
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3650 - accuracy: 1.0000
# Epoch 13/30
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2902 - accuracy: 1.0000
# Epoch 14/30
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2140 - accuracy: 1.0000
# Epoch 15/30
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1450 - accuracy: 1.0000
# Epoch 16/30
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0907 - accuracy: 1.0000
# Epoch 17/30
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 18/30
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 19/30
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 20/30
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 21/30
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 22/30
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 23/30
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 24/30
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 25/30
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 26/30
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 27/30
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 28/30
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 29/30
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 30/30
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0027 - accuracy: 1.0000

# %%
# Перевірка нової рецензії
test_review = "Сьогодні на вулиці прекрасна погода! Чудовий сонячний день."
test_data = tokenizer.texts_to_sequences([test_review])
test_data_pad = pad_sequences(test_data, maxlen=max_text_len)

# Прогнозування класу нової рецензії
prediction = model.predict(test_data_pad)
if prediction > 0.5:
    print("Результат: Позитивна рецензія")
else:
    print("Результат: Негативна рецензія")
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Результат: Позитивна рецензія

# %%
# Перевірка нової рецензії
test_review_1 = "Сірі жахливі хмари, що застилають насуплене небо.".lower()
test_data_1 = tokenizer.texts_to_sequences([test_review_1])
test_data_pad_1 = pad_sequences(test_data_1, maxlen=max_text_len)

# Прогнозування класу нової рецензії
prediction = model.predict(test_data_pad_1)
if prediction > 0.5:
    print("Результат: Позитивна рецензія")
else:
    print("Результат: Негативна рецензія")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Результат: Негативна рецензія
